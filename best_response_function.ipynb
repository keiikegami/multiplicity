# %% [markdown]
# 複数均衡が生まれる時には真ん中の均衡はstableじゃない。（単一の時はstable）
#
# なので端っこの二つのどちらかが現実では実現する。

# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# define best response functions
def br1(sigma2, pop, dist, alpha, beta, delta):
    return np.exp(alpha*pop + beta*dist[0] + delta*sigma2)/(1 + np.exp(alpha*pop + beta*dist[0] + delta*sigma2))
def br2(sigma1, pop, dist, alpha, beta, delta):
    return np.exp(alpha*pop + beta*dist[1] + delta*sigma1)/(1 +np.exp(alpha*pop + beta*dist[1] + delta*sigma1))

# plot function
def BR_plot(pop, dist, alpha, beta, delta):
    grid_num = 200
    grid = np.linspace(0,1,grid_num)
    BRs = np.zeros((grid_num, 2))
    for i in range(grid_num):
        BRs[i, :] = [br1(grid[i], pop, dist, alpha, beta, delta), br2(grid[i], pop, dist, alpha, beta, delta)]
    plt.plot(grid, BRs[:, 1], label = "player 2's BR function")
    plt.plot(BRs[:, 0], grid, label = "player 1's BR function")
    plt.legend()
    plt.xlabel("player 1's entry probability")
    plt.ylabel("player 2's entry probability")

# %% [markdown]
# パラメータを弄って均衡の数を見ていく。
# $pop = 1, dist = [1, 1]$として、$\beta$, $\delta$, $\alpha$のみを変化させていく。
#
# ### 設定1　strategic substitute, small delta

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = 0
delta = 0.3

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定2　strategic complemental, small delta

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = 0
delta = -0.3

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定3　strategic substitude, big delta

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = 3
delta = -15

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定4　strategic complemetal, big delta

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = -3
delta = 15

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定5　strategic complementary, big delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = 0
delta = 10

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定5　strategic substitute, big delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = 0
beta = 0
delta = -10

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定6　preference over entry, substitute small delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = 3
beta = 0
delta = -3

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定7　preference over entry, substitute big delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = 3
beta = 0
delta = -6

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定8　preference over entry, complement big delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = 3
beta = 0
delta = 6

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# ### 設定9　preference over exit, complement big delta, beta = 0

# %%
pop = 1
dist = [2, 1]
alpha = -3
beta = 0
delta = 6

BR_plot(pop, dist, alpha, beta, delta)

# %% [markdown]
# データを発生させるためにうまくパラメータを選ぶ

# %%
# strategic substitue
# betaがある程度小さくないと複数均衡にならない
pop = 1
dist = [1.2, 0.8]
alpha = 1.7
beta = -0.5
delta = -6

BR_plot(pop, dist, alpha, beta, delta)

# %%
# strategic complement
# betaがある程度大きくないと複数均衡にならない
pop = 1
dist = [1.2, 0.8]
alpha = 1.7
beta = -4.5
delta = 6

BR_plot(pop, dist, alpha, beta, delta)
